# %%
import cProfile, pstats, io
import datasetdatabase as dsdb

prod = dsdb.DatasetDatabase(config="/active/configs/aics.json", user="jacksonb")

# %%
pr = cProfile.Profile()
pr.enable()
mito = prod.get_dataset(18)
pr.disable()
# Out:
# Reconstructing dataset...
# [============================================================] 100.0% 4000/4000 ~ 0:0:0 remaining

# %%
s = io.StringIO()
ps = pstats.Stats(pr, stream=s).sort_stats("cumtime")
ps.print_stats()
print(s.getvalue())
# Out:
#          3018420 function calls (3006399 primitive calls) in 598.948 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000  598.948  299.474 /opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2931(run_code)
#         2    0.000    0.000  598.948  299.474 {built-in method builtins.exec}
#         1    0.000    0.000  598.948  598.948 <ipython-input-2-855bebcd2f2f>:3(<module>)
#         1    0.001    0.001  598.948  598.948 /active/datasetdatabase/core.py:627(get_dataset)
#         1    0.278    0.278  598.879  598.879 /active/datasetdatabase/introspect/dataframe.py:280(reconstruct)
#     12004    0.846    0.000  594.609    0.050 /active/datasetdatabase/utils/tools.py:129(get_items_from_db_table)
#     12004    0.293    0.000  587.354    0.049 /opt/conda/lib/python3.6/site-packages/orator/query/builder.py:1043(get)
# ...

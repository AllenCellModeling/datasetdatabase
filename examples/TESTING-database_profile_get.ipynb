# %%
import cProfile, pstats, io
import datasetdatabase as dsdb

prod = dsdb.DatasetDatabase(config="/active/configs/aics.json", user="jacksonb")

# %%
pr = cProfile.Profile()
pr.enable()
mito = prod.get_dataset(18)
pr.disable()
# Out:
# Reconstructing dataset...
# [============================================================] 100.0% 4000/4000 ~ 0:0:0 remaining

# %%
s = io.StringIO()
ps = pstats.Stats(pr, stream=s).sort_stats("cumtime")
ps.print_stats()
print(s.getvalue())
# Out:
#          115321 function calls (115299 primitive calls) in 52.958 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000   52.958   26.479 /opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2931(run_code)
#       3/2    0.000    0.000   52.958   26.479 {built-in method builtins.exec}
#         1    0.000    0.000   52.958   52.958 <ipython-input-2-855bebcd2f2f>:3(<module>)
#         1    0.002    0.002   52.958   52.958 /active/datasetdatabase/core.py:627(get_dataset)
#         1    0.001    0.001   52.885   52.885 /active/datasetdatabase/introspect/dataframe.py:304(reconstruct)
#        20    0.000    0.000   51.942    2.597 /opt/conda/lib/python3.6/threading.py:533(wait)
#        20    0.001    0.000   51.941    2.597 /opt/conda/lib/python3.6/threading.py:263(wait)
#        84   51.939    0.618   51.939    0.618 {method 'acquire' of '_thread.lock' objects}
#         1    0.000    0.000   51.937   51.937 /opt/conda/lib/python3.6/multiprocessing/pool.py:261(map)
#         1    0.000    0.000   51.937   51.937 /opt/conda/lib/python3.6/multiprocessing/pool.py:637(get)
#         1    0.000    0.000   51.937   51.937 /opt/conda/lib/python3.6/multiprocessing/pool.py:634(wait)
#         4    0.000    0.000    0.838    0.210 /active/datasetdatabase/utils/tools.py:129(get_items_from_db_table)
#         4    0.000    0.000    0.452    0.113 /opt/conda/lib/python3.6/site-packages/orator/query/builder.py:1043(get)
#         4    0.001    0.000    0.452    0.113 /opt/conda/lib/python3.6/site-packages/orator/query/builder.py:1067(_run_select)
#         4    0.000    0.000    0.444    0.111 /opt/conda/lib/python3.6/site-packages/orator/connections/connection.py:25(_run)
#         4    0.000    0.000    0.443    0.111 /opt/conda/lib/python3.6/site-packages/orator/connections/connection.py:192(select)
#         4    0.108    0.027    0.384    0.096 /active/datasetdatabase/utils/tools.py:145(<listcomp>)
#         4    0.000    0.000    0.375    0.094 /opt/conda/lib/python3.6/site-packages/psycopg2/extras.py:99(fetchall)
#         4    0.089    0.022    0.375    0.094 {function DictCursorBase.fetchall at 0x7ff765115158}
#     20016    0.154    0.000    0.224    0.000 /opt/conda/lib/python3.6/site-packages/psycopg2/extras.py:172(__setitem__)
#     16014    0.128    0.000    0.188    0.000 /opt/conda/lib/python3.6/site-packages/psycopg2/extras.py:167(__getitem__)
# 40365/40363    0.146    0.000    0.147    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.117    0.117 /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py:334(__init__)
#         1    0.000    0.000    0.112    0.112 /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py:7453(_to_arrays)
#         1    0.000    0.000    0.111    0.111 /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py:7589(_list_of_dict_to_arrays)
#      4002    0.048    0.000    0.110    0.000 /opt/conda/lib/python3.6/site-packages/psycopg2/extras.py:163(__init__)
#      4002    0.044    0.000    0.074    0.000 /opt/conda/lib/python3.6/site-packages/psycopg2/extras.py:199(iterkeys)
#         4    0.000    0.000    0.068    0.017 /opt/conda/lib/python3.6/site-packages/psycopg2/extras.py:141(execute)
#         4    0.067    0.017    0.068    0.017 {function DictCursor.execute at 0x7ff765115378}
#         3    0.014    0.005    0.056    0.019 {built-in method builtins.any}
#         1    0.013    0.013    0.053    0.053 {pandas._libs.lib.fast_unique_multiple_list_gen}
#         1    0.000    0.000    0.047    0.047 /active/datasetdatabase/core.py:848(__init__)
#      4001    0.028    0.000    0.042    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py:7592(<genexpr>)
#         2    0.000    0.000    0.042    0.021 /active/datasetdatabase/utils/tools.py:102(get_object_hash)
#      4001    0.027    0.000    0.040    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py:7591(<genexpr>)
#         2    0.039    0.019    0.040    0.020 {built-in method _pickle.dumps}
#      8006    0.028    0.000    0.028    0.000 {method 'keys' of 'dict' objects}
#         3    0.000    0.000    0.026    0.009 /active/datasetdatabase/core.py:677(get_items_from_table)
#         1    0.000    0.000    0.017    0.017 /opt/conda/lib/python3.6/multiprocessing/dummy/__init__.py:115(Pool)
#      4006    0.015    0.000    0.015    0.000 /opt/conda/lib/python3.6/site-packages/backpack/collections/base_collection.py:787(__iter__)
#      4010    0.015    0.000    0.015    0.000 {built-in method builtins.iter}
# 4095/4090    0.014    0.000    0.015    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.014    0.014 /opt/conda/lib/python3.6/multiprocessing/pool.py:788(__init__)
#         1    0.000    0.000    0.014    0.014 /opt/conda/lib/python3.6/multiprocessing/pool.py:153(__init__)
#         1    0.001    0.001    0.012    0.012 /opt/conda/lib/python3.6/multiprocessing/pool.py:225(_repopulate_pool)
#         1    0.000    0.000    0.011    0.011 /active/datasetdatabase/core.py:748(__init__)
#         1    0.000    0.000    0.010    0.010 /active/datasetdatabase/core.py:826(_validate_info)
#         4    0.000    0.000    0.007    0.002 /opt/conda/lib/python3.6/site-packages/orator/query/builder.py:981(to_sql)
#        19    0.000    0.000    0.007    0.000 /opt/conda/lib/python3.6/threading.py:828(start)
#         4    0.000    0.000    0.007    0.002 /opt/conda/lib/python3.6/site-packages/orator/query/grammars/grammar.py:26(compile_select)
#        16    0.000    0.000    0.007    0.000 /opt/conda/lib/python3.6/multiprocessing/dummy/__init__.py:43(start)
#         4    0.001    0.000    0.007    0.002 /opt/conda/lib/python3.6/site-packages/orator/query/grammars/grammar.py:32(_compile_components)
#       5/2    0.000    0.000    0.004    0.002 <frozen importlib._bootstrap>:966(_find_and_load)
#         4    0.001    0.000    0.004    0.001 /opt/conda/lib/python3.6/site-packages/orator/query/grammars/grammar.py:56(_compile_columns)
#       5/2    0.000    0.000    0.004    0.002 <frozen importlib._bootstrap>:936(_find_and_load_unlocked)
#        16    0.000    0.000    0.004    0.000 /opt/conda/lib/python3.6/multiprocessing/pool.py:783(Process)
#         4    0.002    0.000    0.003    0.001 /opt/conda/lib/python3.6/site-packages/orator/support/grammar.py:63(columnize)
#        16    0.001    0.000    0.003    0.000 /opt/conda/lib/python3.6/multiprocessing/dummy/__init__.py:36(__init__)
#         1    0.000    0.000    0.003    0.003 /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py:7349(_arrays_to_mgr)
#         6    0.000    0.000    0.002    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py:4914(_ensure_index)
#        19    0.001    0.000    0.002    0.000 /opt/conda/lib/python3.6/threading.py:757(__init__)
#         1    0.000    0.000    0.002    0.002 <frozen importlib._bootstrap>:651(_load_unlocked)
#         1    0.000    0.000    0.002    0.002 /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py:4869(create_block_manager_from_arrays)
#       4/2    0.000    0.000    0.002    0.001 <frozen importlib._bootstrap>:211(_call_with_frames_removed)
#        12    0.001    0.000    0.002    0.000 /opt/conda/lib/python3.6/site-packages/orator/support/grammar.py:25(wrap)
#        28    0.001    0.000    0.002    0.000 /active/datasetdatabase/utils/checks.py:45(check_types)
#         1    0.000    0.000    0.002    0.002 {pandas._libs.lib.clean_index_list}
#        19    0.001    0.000    0.001    0.000 {built-in method _thread.start_new_thread}
#         1    0.000    0.000    0.001    0.001 /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py:4880(form_blocks)
#         1    0.001    0.001    0.001    0.001 {built-in method _hashlib.openssl_sha256}
#     41/37    0.000    0.000    0.001    0.000 {method 'join' of 'str' objects}
#         1    0.000    0.000    0.001    0.001 <frozen importlib._bootstrap_external>:672(exec_module)
#       3/1    0.000    0.000    0.001    0.001 {built-in method builtins.__import__}
#         2    0.000    0.000    0.001    0.001 <frozen importlib._bootstrap>:870(_find_spec)
#         1    0.000    0.000    0.001    0.001 /active/datasetdatabase/introspect/dataframe.py:27(__init__)
#         1    0.001    0.001    0.001    0.001 {pandas._libs.lib.dicts_to_array}
#         2    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/base.py:912(__iter__)
#         2    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/base.py:893(tolist)
#         2    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:1149(find_spec)
#         2    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:1117(_get_spec)
#         1    0.001    0.001    0.001    0.001 {built-in method _hashlib.openssl_md5}
#        35    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:997(_handle_fromlist)
#         4    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/orator/database_manager.py:180(__getattr__)
#         4    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/orator/query/grammars/grammar.py:120(_compile_wheres)
#         1    0.000    0.000    0.001    0.001 {built-in method builtins.print}
#         2    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:1233(find_spec)
#         1    0.000    0.000    0.001    0.001 <frozen importlib._bootstrap_external>:743(get_code)
#         2    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/ipykernel/iostream.py:366(write)
#         1    0.000    0.000    0.001    0.001 /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py:7604(_convert_object_array)
#         4    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/orator/database_manager.py:29(connection)
#         1    0.000    0.000    0.001    0.001 /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py:7621(<listcomp>)
#         2    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py:7615(convert)
#         4    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/orator/query/builder.py:327(where)
#         1    0.000    0.000    0.001    0.001 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py:255(__new__)
#       166    0.001    0.000    0.001    0.000 {built-in method builtins.getattr}
#         3    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/dtypes/cast.py:971(maybe_cast_to_datetime)
#         1    0.000    0.000    0.001    0.001 /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py:7644(_homogenize)
#         4    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/orator/connections/connection.py:227(_get_cursor_for_select)
#         2    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py:3412(__getstate__)
#         4    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/orator/query/grammars/grammar.py:70(_compile_from)
#        51    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/threading.py:1230(current_thread)
#         1    0.000    0.000    0.001    0.001 /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py:3265(__init__)
#         3    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/ipykernel/iostream.py:195(schedule)
#         4    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py:3148(get_block_type)
#         4    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/orator/support/grammar.py:19(wrap_table)
#        20    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/threading.py:498(__init__)
#         2    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/series.py:4019(_sanitize_array)
#         1    0.001    0.001    0.001    0.001 /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py:7597(<listcomp>)
#         2    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/dtypes/common.py:647(is_datetimelike)
#         2    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py:3191(make_block)
#         2    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py:3414(<listcomp>)
#        12    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/dtypes/common.py:1835(_get_dtype_type)
#         1    0.000    0.000    0.001    0.001 <frozen importlib._bootstrap>:564(module_from_spec)
#         1    0.000    0.000    0.001    0.001 /opt/conda/lib/python3.6/multiprocessing/pool.py:10(<module>)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py:4972(_simple_blockify)
#        12    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#         6    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py:2067(__getitem__)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/dtypes/cast.py:867(maybe_infer_to_datetimelike)
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/orator/connectors/postgres_connector.py:26(cursor)
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/orator/query/grammars/grammar.py:398(_concatenate)
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/orator/query/grammars/grammar.py:156(_where_basic)
#         5    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:147(__enter__)
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/orator/database_manager.py:51(_parse_connection_name)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/series.py:4036(_try_cast)
#        26    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/encodings/utf_8.py:15(decode)
#         3    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/zmq/sugar/socket.py:334(send)
#        39    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/dtypes/generic.py:7(_check)
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/psycopg2/extras.py:128(cursor)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:504(_init_module_attrs)
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/orator/connections/connection.py:144(table)
#        21    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/threading.py:242(__exit__)
#         3    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/dtypes/inference.py:251(is_list_like)
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py:510(_shallow_copy)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:485(_compile_bytecode)
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/orator/database_manager.py:164(get_default_connection)
#        11    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:57(_path_join)
#        89    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#        22    0.000    0.000    0.000    0.000 <string>:12(__new__)
#         9    0.000    0.000    0.000    0.000 {built-in method builtins.__build_class__}
#        29    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/threading.py:215(__init__)
#         5    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:157(_get_module_lock)
#         5    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/abc.py:180(__instancecheck__)
#        20    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/threading.py:251(_acquire_restore)
#         1    0.000    0.000    0.000    0.000 {built-in method marshal.loads}
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py:4986(_multi_blockify)
#         4    0.000    0.000    0.000    0.000 {function BaseDictConnection.cursor at 0x7ff7650f3a60}
#        19    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/threading.py:1136(daemon)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py:3363(_rebuild_blknos_and_blklocs)
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/dtypes/common.py:1688(is_extension_array_dtype)
#        21    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/_weakrefset.py:81(add)
#        22    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:416(parent)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:75(_path_stat)
#         3    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/dtypes/common.py:407(is_timedelta64_dtype)
#        20    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/threading.py:248(_release_save)
#        21    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/threading.py:239(__enter__)
#        21    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/threading.py:254(_is_owned)
#         4    0.000    0.000    0.000    0.000 {built-in method posix.stat}
#         5    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/dtypes/common.py:227(is_datetimetz)
#        56    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#        53    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.maybe_convert_objects}
#         5    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py:473(_simple_new)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/multiprocessing/pool.py:368(_map_async)
#        61    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#        20    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/orator/support/grammar.py:78(is_expression)
#         6    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py:1982(__reduce__)
#        61    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py:116(__init__)
#        12    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py:920(_get_attributes_dict)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/ipykernel/iostream.py:313(_schedule_flush)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:263(cache_from_source)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py:5017(_stack_arrays)
#        13    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/dtypes/base.py:61(is_dtype)
#        42    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/threading.py:506(is_set)
#        11    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:59(<listcomp>)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:318(__exit__)
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/orator/connections/connection.py:406(_get_elapsed_time)
#        58    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         3    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py:3307(shape)
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/orator/query/builder.py:159(from_)
#         3    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/dtypes/common.py:332(is_datetime64_dtype)
#         3    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/queue.py:27(__init__)
#         1    0.000    0.000    0.000    0.000 /active/datasetdatabase/utils/progressbar.py:18(__init__)
#         5    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/dtypes/common.py:122(is_sparse)
#         8    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/dtypes/common.py:369(is_datetime64tz_dtype)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/abc.py:196(__subclasscheck__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py:3488(_verify_integrity)
#        26    0.000    0.000    0.000    0.000 {built-in method _codecs.utf_8_decode}
#        17    0.000    0.000    0.000    0.000 {built-in method _imp.release_lock}
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/dtypes/common.py:1629(is_extension_type)
#        19    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/threading.py:727(_newname)
#         9    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py:3309(<genexpr>)
#         3    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/dtypes/common.py:195(is_categorical)
#        28    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x7ff79c9e8780}
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/multiprocessing/pool.py:791(_setup_queues)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:403(cached)
#         5    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:176(cb)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:321(<genexpr>)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/common.py:123(_default_index)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/codeop.py:132(__call__)
#        33    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#         5    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:151(__exit__)
#        16    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/weakref.py:354(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:361(_get_cached)
#         3    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/dtypes/common.py:89(is_object_dtype)
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/orator/query/builder.py:1566(get_bindings)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py:237(mgr_locs)
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.round}
#        12    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py:922(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:430(_validate_bytecode_header)
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/orator/connectors/postgres_connector.py:42(__init__)
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/re.py:184(sub)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/range.py:68(__new__)
#         5    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:58(__init__)
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/orator/connections/connection.py:158(query)
#        12    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/orator/support/grammar.py:57(_wrap_value)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py:2298(__init__)
#         6    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py:677(_values)
#         1    0.000    0.000    0.000    0.000 /active/datasetdatabase/utils/progressbar.py:56(update_bar_str)
#        19    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/threading.py:1120(daemon)
#        21    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/orator/support/grammar.py:69(parameter)
#         6    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/compat/__init__.py:205(iteritems)
#        32    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/queue.py:115(put)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/dtypes/common.py:1043(is_datetime64_any_dtype)
#         5    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/dtypes/common.py:513(is_categorical_dtype)
#         3    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/threading.py:1104(is_alive)
#        24    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/psycopg2/extras.py:151(_build_index)
#         7    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:847(__exit__)
#        16    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/weakref.py:406(__setitem__)
#        21    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/range.py:183(__reduce__)
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/orator/query/grammars/grammar.py:73(_compile_joins)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/numpy/core/numeric.py:630(require)
#        21    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/orator/query/builder.py:1587(add_binding)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/dtypes/common.py:1578(is_bool_dtype)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#        24    0.000    0.000    0.000    0.000 {method 'rstrip' of 'str' objects}
#         9    0.000    0.000    0.000    0.000 {built-in method time.time}
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/orator/connections/connection.py:380(_reconnect_if_missing_connection)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/uuid.py:621(uuid4)
#        21    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         5    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:103(release)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py:3784(_consolidate_check)
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/psycopg2/extras.py:69(__init__)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py:5020(_asarray_compat)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/common.py:301(_asarray_tuplesafe)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:830(get_data)
#         7    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:843(__enter__)
#        16    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/threading.py:1087(name)
#        12    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/_weakrefset.py:70(__contains__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/multiprocessing/pool.py:663(__init__)
#         6    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py:672(values)
#        12    0.000    0.000    0.000    0.000 {method 'find' of 'str' objects}
#         5    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:78(acquire)
#         8    0.000    0.000    0.000    0.000 /active/datasetdatabase/utils/tools.py:134(<genexpr>)
#         2    0.000    0.000    0.000    0.000 /active/datasetdatabase/core.py:932(ds)
#        16    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/multiprocessing/util.py:48(debug)
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/orator/query/builder.py:29(__init__)
#        16    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/threading.py:1076(name)
#        17    0.000    0.000    0.000    0.000 {built-in method _imp.acquire_lock}
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/orator/connections/connection.py:384(log_query)
#         5    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/range.py:481(__len__)
#         9    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.array}
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/numpy/core/numeric.py:433(asarray)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py:3785(<listcomp>)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:52(_r_long)
#        12    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:222(_verbose_message)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/range.py:131(_simple_new)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#         1    0.000    0.000    0.000    0.000 {built-in method posix.cpu_count}
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py:5026(_shape_compat)
#         5    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py:641(__len__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/threading.py:334(notify)
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/orator/query/grammars/grammar.py:287(_compile_unions)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/uuid.py:106(__init__)
#        12    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#        14    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py:233(mgr_locs)
#         3    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/threading.py:1062(_wait_for_tstate_lock)
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/orator/connectors/connector.py:111(__getattr__)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/dtypes/common.py:477(is_interval_dtype)
#         1    0.000    0.000    0.000    0.000 /active/datasetdatabase/utils/progressbar.py:66(update_time_str)
#         1    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.ndarray' objects}
#        12    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/_collections_abc.py:252(__subclasshook__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/multiprocessing/pool.py:619(__init__)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py:356(ftype)
#         4    0.000    0.000    0.000    0.000 {method 'sub' of '_sre.SRE_Pattern' objects}
#        11    0.000    0.000    0.000    0.000 /active/datasetdatabase/core.py:927(info)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1228(_get_spec)
#         8    0.000    0.000    0.000    0.000 {built-in method pandas._libs.lib.is_scalar}
#         5    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.empty}
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py:3420(<listcomp>)
#         3    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py:3490(<genexpr>)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:63(_path_split)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/IPython/core/hooks.py:142(__call__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:840(path_stats)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py:1628(__getstate__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/dtypes/cast.py:1207(construct_1d_object_array_from_listlike)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/multiprocessing/util.py:151(__init__)
#         8    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/orator/connections/connection.py:485(pretending)
#         8    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/orator/connections/connection.py:421(get_read_connection)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/dtypes/dtypes.py:707(is_dtype)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:94(_path_isfile)
#         4    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py:3266(<listcomp>)
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/numpy/core/numeric.py:701(<genexpr>)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/ipykernel/iostream.py:300(_is_master_process)
#         8    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/numpy/core/_methods.py:42(_any)
#         5    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#         6    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/dtypes/common.py:858(is_signed_integer_dtype)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/dtypes/common.py:1527(is_float_dtype)
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/re.py:286(_compile)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:524(spec_from_file_location)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:780(find_spec)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:85(_path_is_mode_type)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/range.py:84(_ensure_int)
#         6    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py:635(_reset_identity)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/dtypes/common.py:907(is_unsigned_integer_dtype)
#         6    0.000    0.000    0.000    0.000 {method 'view' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/multiprocessing/pool.py:627(ready)
#         5    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py:3384(_get_items)
#         6    0.000    0.000    0.000    0.000 /active/datasetdatabase/introspect/dataframe.py:38(obj)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py:3311(ndim)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/dtypes/inference.py:388(is_named_tuple)
#         1    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/orator/query/builder.py:1579(set_bindings)
#         6    0.000    0.000    0.000    0.000 /active/datasetdatabase/core.py:950(introspector)
#         6    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py:2445(equals)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/dtypes/inference.py:119(is_iterator)
#         4    0.000    0.000    0.000    0.000 /active/datasetdatabase/core.py:292(db)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/_collections_abc.py:72(_check_methods)
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         5    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:143(__init__)
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/orator/query/processors/processor.py:6(process_select)
#         1    0.000    0.000    0.000    0.000 {method 'read' of '_io.FileIO' objects}
#         1    0.000    0.000    0.000    0.000 <ipython-input-2-855bebcd2f2f>:4(<module>)
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/orator/query/grammars/grammar.py:264(_compile_orders)
#         3    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.arange}
#         3    0.000    0.000    0.000    0.000 {built-in method from_bytes}
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/orator/connections/connection.py:418(get_connection)
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/orator/query/grammars/grammar.py:239(_compile_havings)
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/orator/support/grammar.py:92(get_marker)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/IPython/utils/ipstruct.py:125(__getattr__)
#         4    0.000    0.000    0.000    0.000 {method 'values' of 'collections.OrderedDict' objects}
#         4    0.000    0.000    0.000    0.000 {method 'strip' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/multiprocessing/pool.py:144(Pool)
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/orator/connections/connection.py:280(prepare_bindings)
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/orator/query/grammars/grammar.py:233(_compile_groups)
#         2    0.000    0.000    0.000    0.000 {built-in method pandas._libs.algos.ensure_object}
#         3    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/ipykernel/iostream.py:93(_event_pipe)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:669(create_module)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:861(_find_spec_legacy)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:393(_check_name_wrapper)
#         4    0.000    0.000    0.000    0.000 {method 'lstrip' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method posix.urandom}
#         2    0.000    0.000    0.000    0.000 /active/datasetdatabase/core.py:640(<genexpr>)
#         3    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/queue.py:199(_init)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.setattr}
#         3    0.000    0.000    0.000    0.000 {built-in method posix.fspath}
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py:3413(<listcomp>)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py:4101(_consolidate_inplace)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py:615(is_)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/dtypes/cast.py:853(maybe_castable)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/dtypes/cast.py:1232(construct_1d_ndarray_preserving_na)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/uuid.py:226(__str__)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:1104(user_global_ns)
#         2    0.000    0.000    0.000    0.000 {method 'hexdigest' of '_hashlib.HASH' objects}
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py:124(__init__)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/range.py:177(_get_data_as_items)
#         2    0.000    0.000    0.000    0.000 {built-in method pandas._libs.lib.infer_datetimelike_array}
#         2    0.000    0.000    0.000    0.000 /active/datasetdatabase/core.py:821(origin)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/queue.py:206(_put)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/IPython/core/hooks.py:207(pre_run_code_hook)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1080(_path_importer_cache)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:369(__init__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/multiprocessing/pool.py:76(MaybeEncodingError)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py:1629(<dictcomp>)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py:127(_check_ndim)
#         1    0.000    0.000    0.000    0.000 {pandas._libs.lib.infer_dtype}
#         2    0.000    0.000    0.000    0.000 {method 'fill' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'tolist' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 /active/datasetdatabase/core.py:801(introspector)
#         2    0.000    0.000    0.000    0.000 {built-in method _imp.is_frozen}
#         1    0.000    0.000    0.000    0.000 {built-in method _imp._fix_co_filename}
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:35(_new_module)
#         2    0.000    0.000    0.000    0.000 /active/datasetdatabase/core.py:786(id)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/multiprocessing/context.py:232(get_context)
#         2    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py:3415(<listcomp>)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py:348(shape)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py:352(dtype)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:707(find_spec)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:41(_relax_case)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/multiprocessing/pool.py:59(ExceptionWithTraceback)
#         1    0.000    0.000    0.000    0.000 /active/datasetdatabase/core.py:806(md5)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:311(__enter__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/multiprocessing/pool.py:617(ApplyResult)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/multiprocessing/pool.py:702(IMapIterator)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/multiprocessing/pool.py:780(ThreadPool)
#         1    0.000    0.000    0.000    0.000 /active/datasetdatabase/introspect/dataframe.py:33(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 /active/datasetdatabase/introspect/dataframe.py:32(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py:4990(<lambda>)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/common.py:154(_all_none)
#         1    0.000    0.000    0.000    0.000 /active/datasetdatabase/core.py:816(created)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/six.py:184(find_module)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:800(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:307(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:424(has_location)
#         1    0.000    0.000    0.000    0.000 {method 'count' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.divmod}
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/multiprocessing/pool.py:661(MapResult)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/multiprocessing/pool.py:766(IMapUnorderedIterator)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py:3776(is_consolidated)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/range.py:158(_validate_dtype)
#         1    0.000    0.000    0.000    0.000 {built-in method pandas._libs.lib.is_integer}
#         1    0.000    0.000    0.000    0.000 /active/datasetdatabase/core.py:791(name)
#         1    0.000    0.000    0.000    0.000 /active/datasetdatabase/core.py:796(description)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/multiprocessing/pool.py:53(RemoteTraceback)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:825(get_filename)
#         1    0.000    0.000    0.000    0.000 {method 'remove' of 'collections.deque' objects}

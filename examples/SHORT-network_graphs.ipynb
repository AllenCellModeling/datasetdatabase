# %%
import datasetdatabase as dsdb
mngr = dsdb.ConnectionManager(dsdb.LOCAL, user="jacksonb")
local = mngr.connect(dsdb.LOCAL)
local
# Out:
# Recent Datasets:
# --------------------------------------------------------------------------------
# {'DatasetId': 4, 'Name': 'b9ce3c68d378f0be5a3593f2376f3bf1', 'Description': None, 'SourceId': 5, 'FilepathColumns': 'None', 'Created': '2018-08-03 18:21:09.505811'}
# {'DatasetId': 3, 'Name': 'a42e88544481b7ed167d83ec45585895', 'Description': None, 'SourceId': 4, 'FilepathColumns': 'None', 'Created': '2018-08-03 18:21:00.050009'}
# {'DatasetId': 2, 'Name': 'processing_test', 'Description': 'hello world', 'SourceId': 3, 'FilepathColumns': 'None', 'Created': '2018-08-02 21:40:19.165933'}
# {'DatasetId': 1, 'Name': 'hash_67765affc224a08836c2c79ceebd4982', 'Description': None, 'SourceId': 1, 'FilepathColumns': 'None', 'Created': '2018-08-02 19:56:37.671832'}

# %%
local.get_dataset_connections(2)
# Out:
#                alg                                   from  \
# 0  some_weird_func  hash_67765affc224a08836c2c79ceebd4982
# 1  some_weird_func                        processing_test
# 2  some_weird_func       a42e88544481b7ed167d83ec45585895
# 3  some_weird_func                        processing_test
# 4  some_weird_func                        processing_test
#
#                                  to
# 0                   processing_test
# 1  a42e88544481b7ed167d83ec45585895
# 2  b9ce3c68d378f0be5a3593f2376f3bf1
# 3  d62ebff152a58d1d270e74c89b37e972
# 4  bb0bebfae55b462e9cb51996a058f19d

# %%
local.display_dataset_graph(2)

# %%
import datasetdatabase as dsdb

# %%
dsdb.LOCAL
# Out:
# {'name': 'LOCAL', 'driver': 'sqlite', 'database': PosixPath('local.db')}

# %%
import pandas as pd
import numpy as np
import pathlib
import json

# for reproducibility I will set the seed here
np.random.seed(seed=12)

test = []
for i in range(300):
    d = {}
    d["strings"] = "foo" + str(i)
    d["bools"] = np.random.rand() < 0.5
    d["floats"] = np.random.rand() * 100
    d["ndarrays"] = np.random.rand(2, 2)
    d["tuples"] = tuple([1, 2, 3])
    d["sets"] = set([1, 2, 3, 3, 3])
    d["files"] = str(pathlib.Path("./EXPLAINER-connection_manager.ipynb"))
    test.append(d)

# convert this example both to dataframe
test = pd.DataFrame(test)
test
# Out:
#      bools                               files     floats  \
# 0     True  EXPLAINER-connection_manager.ipynb  74.004970
# 1    False  EXPLAINER-connection_manager.ipynb   3.342143
# 2    False  EXPLAINER-connection_manager.ipynb  85.273554
# 3    False  EXPLAINER-connection_manager.ipynb  16.071675
# 4     True  EXPLAINER-connection_manager.ipynb  67.145265
# 5    False  EXPLAINER-connection_manager.ipynb  32.756948
# 6    False  EXPLAINER-connection_manager.ipynb  82.500925
# 7     True  EXPLAINER-connection_manager.ipynb  96.259690
# 8     True  EXPLAINER-connection_manager.ipynb   3.516826
# 9     True  EXPLAINER-connection_manager.ipynb  22.085252
# 10   False  EXPLAINER-connection_manager.ipynb  80.351665
# 11   False  EXPLAINER-connection_manager.ipynb  46.144026
# 12    True  EXPLAINER-connection_manager.ipynb  88.844753
# 13    True  EXPLAINER-connection_manager.ipynb  66.525743
# 14   False  EXPLAINER-connection_manager.ipynb  92.433070
# 15   False  EXPLAINER-connection_manager.ipynb  40.595834
# 16   False  EXPLAINER-connection_manager.ipynb  91.986487
# 17   False  EXPLAINER-connection_manager.ipynb  59.961919
# 18    True  EXPLAINER-connection_manager.ipynb  21.060764
# 19    True  EXPLAINER-connection_manager.ipynb  64.795917
# 20    True  EXPLAINER-connection_manager.ipynb  40.258915
# 21    True  EXPLAINER-connection_manager.ipynb  60.500539
# 22    True  EXPLAINER-connection_manager.ipynb  33.472408
# 23    True  EXPLAINER-connection_manager.ipynb  31.566824
# 24    True  EXPLAINER-connection_manager.ipynb  24.178024
# 25   False  EXPLAINER-connection_manager.ipynb  65.934335
# 26    True  EXPLAINER-connection_manager.ipynb  98.862787
# 27    True  EXPLAINER-connection_manager.ipynb  57.443279
# 28    True  EXPLAINER-connection_manager.ipynb  41.893868
# 29   False  EXPLAINER-connection_manager.ipynb  96.918238
# ..     ...                                 ...        ...
# 270   True  EXPLAINER-connection_manager.ipynb   2.422076
# 271  False  EXPLAINER-connection_manager.ipynb  45.685658
# 272  False  EXPLAINER-connection_manager.ipynb  62.369186
# 273  False  EXPLAINER-connection_manager.ipynb  56.873168
# 274  False  EXPLAINER-connection_manager.ipynb  10.817166
# 275   True  EXPLAINER-connection_manager.ipynb  15.119607
# 276  False  EXPLAINER-connection_manager.ipynb   5.638259
# 277  False  EXPLAINER-connection_manager.ipynb  93.000373
# 278   True  EXPLAINER-connection_manager.ipynb  81.991375
# 279  False  EXPLAINER-connection_manager.ipynb  97.756871
# 280  False  EXPLAINER-connection_manager.ipynb  59.568756
# 281  False  EXPLAINER-connection_manager.ipynb  25.502396
# 282   True  EXPLAINER-connection_manager.ipynb   2.267419
# 283   True  EXPLAINER-connection_manager.ipynb  14.214076
# 284  False  EXPLAINER-connection_manager.ipynb  54.981229
# 285   True  EXPLAINER-connection_manager.ipynb  23.558532
# 286  False  EXPLAINER-connection_manager.ipynb  45.461718
# 287  False  EXPLAINER-connection_manager.ipynb  88.358637
# 288   True  EXPLAINER-connection_manager.ipynb  93.674298
# 289   True  EXPLAINER-connection_manager.ipynb  76.141656
# 290   True  EXPLAINER-connection_manager.ipynb  26.665810
# 291   True  EXPLAINER-connection_manager.ipynb  86.333416
# 292   True  EXPLAINER-connection_manager.ipynb  89.406016
# 293  False  EXPLAINER-connection_manager.ipynb   7.932652
# 294   True  EXPLAINER-connection_manager.ipynb   9.429712
# 295  False  EXPLAINER-connection_manager.ipynb  85.857218
# 296  False  EXPLAINER-connection_manager.ipynb  17.251139
# 297  False  EXPLAINER-connection_manager.ipynb  86.924103
# 298   True  EXPLAINER-connection_manager.ipynb  59.036291
# 299   True  EXPLAINER-connection_manager.ipynb  98.157753
#
#                                               ndarrays       sets strings  \
# 0    [[0.26331501518513467, 0.5337393933802977], [0...  {1, 2, 3}    foo0
# 1    [[0.9569493362751168, 0.13720932135607644], [0...  {1, 2, 3}    foo1
# 2    [[0.002259233518513537, 0.5212260272202929], [...  {1, 2, 3}    foo2
# 3    [[0.7645604503388788, 0.020809797952066167], [...  {1, 2, 3}    foo3
# 4    [[0.4712297782500141, 0.8161682980460269], [0....  {1, 2, 3}    foo4
# 5    [[0.3346475291060558, 0.9780580790165189], [0....  {1, 2, 3}    foo5
# 6    [[0.40664030180666166, 0.4513084114213143], [0...  {1, 2, 3}    foo6
# 7    [[0.4192502702591062, 0.4240524465509987], [0....  {1, 2, 3}    foo7
# 8    [[0.08427266973184566, 0.7325206981419501], [0...  {1, 2, 3}    foo8
# 9    [[0.055019993340200135, 0.5232460707782919], [...  {1, 2, 3}    foo9
# 10   [[0.11360171953981701, 0.2771172144251962], [0...  {1, 2, 3}   foo10
# 11   [[0.8947430739278908, 0.6057776931355849], [0....  {1, 2, 3}   foo11
# 12   [[0.2085004884601801, 0.9445814621563249], [0....  {1, 2, 3}   foo12
# 13   [[0.6373854951409694, 0.862465162297615], [0.9...  {1, 2, 3}   foo13
# 14   [[0.6194234667677466, 0.32258573270881385], [0...  {1, 2, 3}   foo14
# 15   [[0.9465558223628031, 0.8571905588319436], [0....  {1, 2, 3}   foo15
# 16   [[0.0059093558684842895, 0.6429261484358456], ...  {1, 2, 3}   foo16
# 17   [[0.3122839968432516, 0.06987367476308803], [0...  {1, 2, 3}   foo17
# 18   [[0.3774407823606447, 0.40284721017267344], [0...  {1, 2, 3}   foo18
# 19   [[0.511642952793331, 0.3338324855146031], [0.7...  {1, 2, 3}   foo19
# 20   [[0.7868444652477247, 0.2538081939276894], [0....  {1, 2, 3}   foo20
# 21   [[0.29012193658782715, 0.6265293919225703], [0...  {1, 2, 3}   foo21
# 22   [[0.1775063672167354, 0.008003339782281182], [...  {1, 2, 3}   foo22
# 23   [[0.9686183289699668, 0.8735825512370129], [0....  {1, 2, 3}   foo23
# 24   [[0.4909549698249829, 0.5439434095685136], [0....  {1, 2, 3}   foo24
# 25   [[0.14922368526773322, 0.7465837898057559], [0...  {1, 2, 3}   foo25
# 26   [[0.3445949402799181, 0.34344500065127515], [0...  {1, 2, 3}   foo26
# 27   [[0.7776794520796216, 0.9498820771377502], [0....  {1, 2, 3}   foo27
# 28   [[0.6320315467138395, 0.09547025346487126], [0...  {1, 2, 3}   foo28
# 29   [[0.7434179682255139, 0.5176892950354683], [0....  {1, 2, 3}   foo29
# ..                                                 ...        ...     ...
# 270  [[0.974122020587236, 0.44618734324795695], [0....  {1, 2, 3}  foo270
# 271  [[0.9824805818798799, 0.6807660392817135], [0....  {1, 2, 3}  foo271
# 272  [[0.28487615641122266, 0.8966137280560189], [0...  {1, 2, 3}  foo272
# 273  [[0.2219867139855145, 0.06273081703775074], [0...  {1, 2, 3}  foo273
# 274  [[0.6115424461918687, 0.3092652169851944], [0....  {1, 2, 3}  foo274
# 275  [[0.9849207747724451, 0.9743846796801151], [0....  {1, 2, 3}  foo275
# 276  [[0.8253952347716951, 0.4339006789213188], [0....  {1, 2, 3}  foo276
# 277  [[0.46354151395360743, 0.15785252967390762], [...  {1, 2, 3}  foo277
# 278  [[0.34000608927647813, 0.22596491685430242], [...  {1, 2, 3}  foo278
# 279  [[0.0707965846423314, 0.31656499554626116], [0...  {1, 2, 3}  foo279
# 280  [[0.5405748880266737, 0.21728899988152017], [0...  {1, 2, 3}  foo280
# 281  [[0.10589323680061347, 0.6159951702540241], [0...  {1, 2, 3}  foo281
# 282  [[0.5834716444016353, 0.6535604544645702], [0....  {1, 2, 3}  foo282
# 283  [[0.956049141538781, 0.5814111624510557], [0.6...  {1, 2, 3}  foo283
# 284  [[0.9315071644964158, 0.3778167413568866], [0....  {1, 2, 3}  foo284
# 285  [[0.030212969802915213, 0.38792080706260135], ...  {1, 2, 3}  foo285
# 286  [[0.3448117016531671, 0.09309324213887771], [0...  {1, 2, 3}  foo286
# 287  [[0.511967247031543, 0.013128026550336513], [0...  {1, 2, 3}  foo287
# 288  [[0.7580462589664934, 0.31748523538591067], [0...  {1, 2, 3}  foo288
# 289  [[0.5549239353104213, 0.7293236899682891], [0....  {1, 2, 3}  foo289
# 290  [[0.6324570909349416, 0.5790362585652593], [0....  {1, 2, 3}  foo290
# 291  [[0.9487924821088674, 0.18508071011502103], [0...  {1, 2, 3}  foo291
# 292  [[0.32616278006303223, 0.5184990604103303], [0...  {1, 2, 3}  foo292
# 293  [[0.5317547243492127, 0.7153421660181054], [0....  {1, 2, 3}  foo293
# 294  [[0.047551990931078425, 0.9218185117929207], [...  {1, 2, 3}  foo294
# 295  [[0.04385095552500806, 0.12201863199444263], [...  {1, 2, 3}  foo295
# 296  [[0.2804574901390233, 0.3221458547164132], [0....  {1, 2, 3}  foo296
# 297  [[0.7449990661799628, 0.9435554535553152], [0....  {1, 2, 3}  foo297
# 298  [[0.37665498872306646, 0.5760473423850961], [0...  {1, 2, 3}  foo298
# 299  [[0.22691454887822515, 0.04156117313378749], [...  {1, 2, 3}  foo299
#
#         tuples
# 0    (1, 2, 3)
# 1    (1, 2, 3)
# 2    (1, 2, 3)
# 3    (1, 2, 3)
# 4    (1, 2, 3)
# 5    (1, 2, 3)
# 6    (1, 2, 3)
# 7    (1, 2, 3)
# 8    (1, 2, 3)
# 9    (1, 2, 3)
# 10   (1, 2, 3)
# 11   (1, 2, 3)
# 12   (1, 2, 3)
# 13   (1, 2, 3)
# 14   (1, 2, 3)
# 15   (1, 2, 3)
# 16   (1, 2, 3)
# 17   (1, 2, 3)
# 18   (1, 2, 3)
# 19   (1, 2, 3)
# 20   (1, 2, 3)
# 21   (1, 2, 3)
# 22   (1, 2, 3)
# 23   (1, 2, 3)
# 24   (1, 2, 3)
# 25   (1, 2, 3)
# 26   (1, 2, 3)
# 27   (1, 2, 3)
# 28   (1, 2, 3)
# 29   (1, 2, 3)
# ..         ...
# 270  (1, 2, 3)
# 271  (1, 2, 3)
# 272  (1, 2, 3)
# 273  (1, 2, 3)
# 274  (1, 2, 3)
# 275  (1, 2, 3)
# 276  (1, 2, 3)
# 277  (1, 2, 3)
# 278  (1, 2, 3)
# 279  (1, 2, 3)
# 280  (1, 2, 3)
# 281  (1, 2, 3)
# 282  (1, 2, 3)
# 283  (1, 2, 3)
# 284  (1, 2, 3)
# 285  (1, 2, 3)
# 286  (1, 2, 3)
# 287  (1, 2, 3)
# 288  (1, 2, 3)
# 289  (1, 2, 3)
# 290  (1, 2, 3)
# 291  (1, 2, 3)
# 292  (1, 2, 3)
# 293  (1, 2, 3)
# 294  (1, 2, 3)
# 295  (1, 2, 3)
# 296  (1, 2, 3)
# 297  (1, 2, 3)
# 298  (1, 2, 3)
# 299  (1, 2, 3)
#
# [300 rows x 7 columns]

# %%
t = dsdb.Dataset(test,
                 name="test dataset",
                 description="this is the hello world of dataset creation",
                 filepath_columns="files",
                 type_validation_map={"bools": bool,
                                      "files": str,
                                      "floats": float,
                                      "ndarrays": np.ndarray,
                                      "sets": set,
                                      "strings": str,
                                      "tuples": tuple},
                 value_validation_map={"tuples": lambda x: x == (1, 2, 3),
                                       "floats": lambda x: x >= 0},
                 import_as_type_map=True)
t
# Out:
# Casting values to type map...
# [============================================================] 100.0% 2100/2100 ~ 0:0:0 remaining
# Checking files exist...
# [============================================================] 100.0% 300/300 ~ 0:0:0 remaining
# Checking dataset value types...
# [============================================================] 100.0% 2100/2100 ~ 0:0:0 remaining
# Checking dataset values...
# [============================================================] 100.0% 600/600 ~ 0:0:0 remaining
# info: None
# df: True
# name: test dataset
# description: this is the hello world of dataset creation
# filepath_columns: files
# validated_items: {'types': True, 'values': True, 'files': True}

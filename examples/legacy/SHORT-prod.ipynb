# %%
import datasetdatabase as dsdb
mngr = dsdb.ConnectionManager("/active/configs/aics.json", user="jacksonb")
prod = mngr.connect("prod")
prod
# Out:
# Recent Datasets:
# --------------------------------------------------------------------------------
# {'DatasetId': 1, 'Name': 'MitoEval20180731', 'Description': 'Recent Handoff Data for Mito-classification', 'SourceId': 2, 'FilepathColumns': 'None', 'Created': datetime.datetime(2018, 7, 31, 17, 3, 25, 87825)}

# %%
# %time df = prod.get_dataset(1)
df
# Out:
# CPU times: user 3min 2s, sys: 4.12 s, total: 3min 6s
# Wall time: 3min 33s
#       DeliveryDate  FinalScore  Index  SegmentationXyPixelSize  \
# 0       2017_03_28           1      1                    0.065
# 1       2017_03_28           1      1                    0.065
# 2       2017_03_28           1      1                    0.065
# 3       2017_03_28           1      1                    0.065
# 4       2017_03_28           1      1                    0.065
# 5       2017_03_28           1      1                    0.065
# 6       2017_03_28           1      2                    0.065
# 7       2017_03_28           1      2                    0.065
# 8       2017_03_28           1      2                    0.065
# 9       2017_03_28           1      2                    0.065
# 10      2017_03_28           1      2                    0.065
# 11      2017_03_28           1      2                    0.065
# 12      2017_03_28           1      3                    0.065
# ...

# %%
prod._deep_print()
# Out:
# ------------------------------- DATASET DATABASE -------------------------------
# --------------------------------------------------------------------------------
# Recent QuiltSource:
# --------------------------------------------------------------------------------
# Recent FileSource:
# {'FileSourceId': 1, 'FileId': 1, 'SourceId': 2, 'Created': datetime.datetime(2018, 7, 31, 16, 33, 18, 24414)}
# --------------------------------------------------------------------------------
# Recent Dataset:
# {'DatasetId': 1, 'Name': 'MitoEval20180731', 'Description': 'Recent Handoff Data for Mito-classification', 'SourceId': 2, 'FilepathColumns': 'None', 'Created': datetime.datetime(2018, 7, 31, 17, 3, 25, 87825)}
# --------------------------------------------------------------------------------
# Recent Iota:
# ...
